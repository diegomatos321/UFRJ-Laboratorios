# %%
using LinearAlgebra
import Pkg; Pkg.add("Images")
import Pkg; Pkg.add("JLD")
using Images # read and show images, more info here: https://github.com/JuliaImages/Images.jl
using JLD # used for File I/O, more info here: https://github.com/JuliaIO/JLD.jl
using Plots
# Out:
#     Updating registry at `C:\Users\jarpa\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#   No Changes to `C:\Users\jarpa\.julia\environments\v1.6\Project.toml`
#   No Changes to `C:\Users\jarpa\.julia\environments\v1.6\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\jarpa\.julia\environments\v1.6\Project.toml`
#   No Changes to `C:\Users\jarpa\.julia\environments\v1.6\Manifest.toml`

# %%
function compressão(A,k) #determine B(m,k) e C(k,n) tal que A(m,n) é aproximadamente B*C
    m,n=size(A)
    local C
    B=randn(m,k) #matrix aleatória m por k "sorteio da base inicial"
    #alternating least squares
    for i=1:100
        C=B\A
        B=A/C    
    end
    erro=norm(A-B*C)
    return B,C,erro
end
# Out:
# compressão (generic function with 1 method)

# %%
A= [1 2 1 11 101 1001;1 2 2 12 102 1002;1 2 3 13 103 1003]
# Out:
# 3×6 Matrix{Int64}:
#  1  2  1  11  101  1001
#  1  2  2  12  102  1002
#  1  2  3  13  103  1003

# %%
B=[1 1; 1 2; 1 3]
#C=B\A
# Out:
# 3×2 Matrix{Int64}:
#  1  1
#  1  2
#  1  3

# %%
B,C,erro=compressão(A,2)
# Out:
# ([0.33776249255941393 0.7737886263558043; -0.06907783074011777 0.5926527453890572; -0.5609959341272067 0.3736117667486517], [-0.9104494260123649 -1.5801813230367463 … -74.59934097380153 -717.7126117333084; 1.4909225534197772 3.1860763793845965 … 163.47780182229238 1607.009694810205], 0.1705578248894144)

# %%
A= [1 2 1 11 101 1001;1 2 2 12 102 1002;1 2 3 13 103 1003]+0.1*randn(3,6)
# Out:
# 3×6 Matrix{Float64}:
#  0.829251  1.9793   1.15203  11.0078  101.264  1001.07
#  0.977353  1.9103   2.07118  11.7999  102.105  1001.97
#  1.05381   2.11626  3.0839   13.003   102.897  1003.03

# %%
img = load("simples.jpg");
display(Gray.([img 2.0*img 0.5*img]))
# Out:
# 630×1890 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)       …  Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)       …  Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)       …  Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  Gray{Float64}(1.0)       Gray{Float64}(1.0)          Gray{Float64}(0.5)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)  …  Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)  …  Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)
#  Gray{Float64}(0.950149)  Gray{Float64}(0.950149)     Gray{Float64}(0.475075)

# %%
img = load("bandeira.jpg");
#display(Gray.([2*img 1.5*img img]))
display(Gray.(img))
# Get image as a raw matrix
bandeira = channelview(Gray.(img[:,:]));
# Out:
# 526×1000 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.133)     Gray{N0f8}(0.267)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.251)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.251)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.255)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.251)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.353)  Gray{N0f8}(0.247)     Gray{N0f8}(0.259)
#  Gray{N0f8}(0.42)   Gray{N0f8}(0.314)  …  Gray{N0f8}(0.329)

# %%
bandeira_ruidosa=bandeira+0.05*randn(526,1000)
display(Gray.(bandeira_ruidosa))
# Out:
# 526×1000 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.125097)  …  Gray{Float64}(0.305052)
#  Gray{Float64}(0.245978)     Gray{Float64}(0.209128)
#  Gray{Float64}(0.190941)     Gray{Float64}(0.226236)
#  Gray{Float64}(0.247413)     Gray{Float64}(0.304708)
#  Gray{Float64}(0.178061)     Gray{Float64}(0.227102)
#  Gray{Float64}(0.168717)  …  Gray{Float64}(0.196896)
#  Gray{Float64}(0.158968)     Gray{Float64}(0.212249)
#  Gray{Float64}(0.210362)     Gray{Float64}(0.271406)
#  Gray{Float64}(0.201425)     Gray{Float64}(0.241202)
#  Gray{Float64}(0.224239)     Gray{Float64}(0.208495)
#  Gray{Float64}(0.213088)  …  Gray{Float64}(0.302937)
#  Gray{Float64}(0.264319)     Gray{Float64}(0.295669)
#  Gray{Float64}(0.198907)     Gray{Float64}(0.258841)
#  ⋮                        ⋱
#  Gray{Float64}(0.432289)     Gray{Float64}(0.262529)
#  Gray{Float64}(0.302495)  …  Gray{Float64}(0.280287)
#  Gray{Float64}(0.358613)     Gray{Float64}(0.386416)
#  Gray{Float64}(0.325961)     Gray{Float64}(0.295901)
#  Gray{Float64}(0.484822)     Gray{Float64}(0.220238)
#  Gray{Float64}(0.243017)     Gray{Float64}(0.328308)
#  Gray{Float64}(0.405234)  …  Gray{Float64}(0.302288)
#  Gray{Float64}(0.363995)     Gray{Float64}(0.26493)
#  Gray{Float64}(0.520164)     Gray{Float64}(0.224495)
#  Gray{Float64}(0.349343)     Gray{Float64}(0.282259)
#  Gray{Float64}(0.366418)     Gray{Float64}(0.256109)
#  Gray{Float64}(0.438412)  …  Gray{Float64}(0.327045)

# %%
rank(bandeira), rank(bandeira_ruidosa)
# Out:
# (114, 526)

# %%
size(bandeira)
# Out:
# (526, 1000)

# %%
B,C,erro=compressão(bandeira,6)
bandeira_comprimida=B*C
display(Gray.(bandeira_comprimida))
# Out:
# 526×1000 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)  …  Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)  …  Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)  …  Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  Gray{Float64}(0.157451)  Gray{Float64}(0.135461)     Gray{Float64}(0.266683)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)  …  Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.27623)   Gray{Float64}(0.265572)  …  Gray{Float64}(0.2667)
#  Gray{Float64}(0.27623)   Gray{Float64}(0.265572)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276255)  Gray{Float64}(0.265601)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.276218)  Gray{Float64}(0.265558)     Gray{Float64}(0.2667)
#  Gray{Float64}(0.268137)  Gray{Float64}(0.257797)     Gray{Float64}(0.258856)
#  Gray{Float64}(0.341165)  Gray{Float64}(0.327992)  …  Gray{Float64}(0.329448)

# %%
bandeira

# %%
n=30
erro=zeros(n,1)
for i=1:n
    B,C,erro[i]=compressão(bandeira,i)
end

plot(erro)

# %%
size(bandeira)
# Out:
# (526, 1000)

# %%
15260/526000
# Out:
# 0.029011406844106465
